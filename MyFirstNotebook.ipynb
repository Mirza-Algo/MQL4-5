# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <b>Muhammad Mubashir Mirza.</b><br>
# Data Scientist.

# %% [markdown]
# <i> I am interested in data science because I can make informed decisions for my company by utilizing the various and powerful tools and techniques provided by this modern discipline.  </i>

# %% [markdown]
# <h3>The following code creates a plot between x and y sets.</h3>

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
import matplotlib.pyplot as plt
plt.plot(x, y)

# %% [markdown]
# <s>No horizontal rule</s>

# %% [markdown]
# <li> For business:</li><br><li><mark>mirza.mubashir786@hotmail.com</mark></li>

# %% [markdown]
# ![IMG-20191126-WA0010-2.jpg](attachment:IMG-20191126-WA0010-2.jpg)
